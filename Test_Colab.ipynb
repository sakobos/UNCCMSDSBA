# %% [markdown]
# <a href="https://colab.research.google.com/github/sakobos/UNCCMSDSBA/blob/main/Test_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Testing connection to GitHub")
# Out:
# Testing connection to GitHub

# %%
even_numbers = [0, 2, 4, 6, 8]
print(even_numbers)
# Out:
# [0, 2, 4, 6, 8]
